# %% [markdown]
# <a href="https://colab.research.google.com/github/vinodhiniarji14-coder/IIy-IIIs-python/blob/main/Unit5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.plot(x, y, marker="o", color="red", linewidth="2.5", label="Line")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Simple Line Plot")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y1 = [2, 4, 6, 8, 10]
y2 = [1, 4, 9, 16, 25]

plt.subplot(1, 3, 1)
plt.plot(x, y1, color="blue", marker="o")
plt.title("Line Plot")

plt.subplot(1, 3, 2)
plt.scatter(x, y2, color="red")
plt.title("Scatter Plot")

plt.subplot(1, 3, 3)
plt.bar(x, y2, color="green")
plt.title("Bar Plot")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

categories = ["A", "B", "C", "D"]
values = [4, 7, 2, 9]

plt.bar(categories, values, color="orange")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.title("Simple Bar Plot")
plt.show()

plt.barh(categories, values, color="green")
plt.xlabel("Values")
plt.ylabel("Categories")
plt.title("Horizontal Bar Plot")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))
ax.plot_surface(X, Y, Z, cmap="viridis")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.set_title("3D Surface Plot")
plt.show()
